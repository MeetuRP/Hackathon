# %%
# %pip install uvicorn
# %pip install fastapi 
# %pip install uvicorn 
# %pip install pandas 
# %pip install scikit-learn 
# %pip install numpy 
# %pip install joblib 
# %pip install python-socketio
# %pip install requests
# %pip install haversine
# %pip install xgboost
# %pip install supabase
# %pip install python-jose[cryptography]
# %pip install passlib[bcrypt]
# %pip install python-dotenv
# Out:
# Requirement already satisfied: uvicorn in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (0.35.0)
# Requirement already satisfied: click>=7.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\jigar\appdata\roaming\python\python312\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fastapi in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (0.116.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from fastapi) (2.11.8)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: uvicorn in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (0.35.0)
# Requirement already satisfied: click>=7.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\jigar\appdata\roaming\python\python312\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jigar\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: joblib in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (1.5.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-socketio in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (5.13.0)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-socketio) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-socketio) (4.12.2)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-engineio>=4.11.0->python-socketio) (1.1.0)
# Requirement already satisfied: wsproto in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from requests) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: haversine in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (2.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from xgboost) (2.3.3)
# Requirement already satisfied: scipy in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from xgboost) (1.16.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: supabase in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (2.18.1)
# Requirement already satisfied: postgrest==1.1.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase) (1.1.1)
# Requirement already satisfied: realtime==2.7.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase) (2.7.0)
# Requirement already satisfied: supabase-auth==2.12.3 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase) (2.12.3)
# Requirement already satisfied: storage3==0.12.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase) (0.12.1)
# Requirement already satisfied: supabase-functions==0.10.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase) (0.10.1)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase) (0.28.1)
# Requirement already satisfied: deprecation<3.0.0,>=2.1.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from postgrest==1.1.1->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from postgrest==1.1.1->supabase) (2.11.8)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from realtime==2.7.0->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from realtime==2.7.0->supabase) (15.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\jigar\appdata\roaming\python\python312\site-packages (from storage3==0.12.1->supabase) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase-auth==2.12.3->supabase) (2.10.1)
# Requirement already satisfied: strenum<0.5.0,>=0.4.15 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from supabase-functions==0.10.1->supabase) (0.4.15)
# Requirement already satisfied: packaging in c:\users\jigar\appdata\roaming\python\python312\site-packages (from deprecation<3.0.0,>=2.1.0->postgrest==1.1.1->supabase) (25.0)
# Requirement already satisfied: anyio in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.10.0)
# Requirement already satisfied: certifi in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from httpx[http2]<0.29,>=0.26->postgrest==1.1.1->supabase) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==1.1.1->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==1.1.1->supabase) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==1.1.1->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==1.1.1->supabase) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==1.1.1->supabase) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\roaming\python\python312\site-packages (from python-dateutil<3.0.0,>=2.8.2->storage3==0.12.1->supabase) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from anyio->httpx<0.29,>=0.26->supabase) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-jose[cryptography] in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (3.5.0)
# Requirement already satisfied: ecdsa!=0.15 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-jose[cryptography]) (0.19.1)
# Requirement already satisfied: rsa!=4.1.1,!=4.4,<5.0,>=4.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-jose[cryptography]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.5.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-jose[cryptography]) (0.6.1)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from python-jose[cryptography]) (45.0.7)
# Requirement already satisfied: cffi>=1.14 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from cryptography>=3.4.0->python-jose[cryptography]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from cffi>=1.14->cryptography>=3.4.0->python-jose[cryptography]) (2.23)
# Requirement already satisfied: six>=1.9.0 in c:\users\jigar\appdata\roaming\python\python312\site-packages (from ecdsa!=0.15->python-jose[cryptography]) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: passlib[bcrypt] in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (1.7.4)
# Requirement already satisfied: bcrypt>=3.1.0 in c:\users\jigar\anaconda3\envs\ljvenv\lib\site-packages (from passlib[bcrypt]) (4.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-dotenv
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
# Note: you may need to restart the kernel to use updated packages.
